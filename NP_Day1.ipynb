# %% [markdown]
# # Heading1
# ## Heading2
# ### Heading3
# #### Heading4
# ##### Heading5
# ###### Heading6

# %% [markdown]
# *Italic text*
#
#
# **Bold text**

# %% [markdown]
# - Item1
# - Item2
# - Item3
# 1. Item1
# 2. Item2
# 3. Item3
#
# A. Item1
#
#
# B. Item2

# %% [markdown]
# `print("Hello")`

# %% [markdown]
# ```python
# print("Hello Divya")

# %% [markdown]
# ```python
# print("Hello divya")
# print("Divya")
# ```

# %% [markdown]
# This is a line<br>This is a second line<br> This is the third line

# %% [markdown]
# ---

# %% [markdown]
# | Name | Marks | Grade |
# |------|-------|-------|
# | Divya | 95 | A |
# | Rahul | 88 | B |
# | Anu | 91 | A |

# %% [markdown]
# |A|B|
# |-|-|
# |1|2|

# %% [markdown]
# > Important
# >
# > Very Important

# %%
# %time sum(range(100))
# Out:
# CPU times: total: 0 ns
# Wall time: 5.25 μs
# 4950

# %%
# %history
# Out:
# # Heading1
# ## Heading2
# -Item1
# -Item2
# -Item3
# `print("Hello")`
# ```python
# print("Hello Divya")```
# %time
# %time
# %time sum(range(100))
# %history

# %%
# %pwd
# Out:
# 'C:\\Users\\DIVYA\\Jupyter_Notebook'

# %%
# %ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is E831-1C77
#
#  Directory of C:\Users\DIVYA\Jupyter_Notebook
#
# 29-05-2026  15:42    <DIR>          .
# 29-05-2026  14:32    <DIR>          ..
# 29-05-2026  14:33    <DIR>          .ipynb_checkpoints
# 29-05-2026  15:42             4,291 Type.ipynb
#                1 File(s)          4,291 bytes
#                3 Dir(s)  67,314,552,832 bytes free

# %%
# %who
# Out:
# Interactive namespace is empty.

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  n
# Nothing done.

# %%
# %%writefile sample.py
print("hi python")
# Out:
# Overwriting sample.py

# %%
# %run sample.py
# Out:
# hi python

# %%
# %%html
#
# <h1>Hello Divya</h1>
# Out:
# <h1>Hello Divya</h1>

# %%
# %%time

for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# CPU times: total: 0 ns
# Wall time: 169 μs
